# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd

# # Read the CSV file specifying the encoding 'latin1'
# df_i = pd.read_csv("https://data.london.gov.uk/download/london-fire-brigade-incident-records/f5066d66-c7a3-415f-9629-026fbda61822/LFB%20Incident%20data%20from%202018%20onwards.csv", encoding='latin1', header=0)

# # Display the first and last 10 rows
# print(df_i.head(10))
# print(df_i.tail(10))

# # Print the data types of each column to check the data type of 'CalYear'
# print(df_i.dtypes)

# # Filter the DataFrame to include only rows where CalYear is 2023
# df_i = df_i[df_i['CalYear'] == 2023]

# # Randomly select 10,000 rows from the filtered DataFrame
# df_i = df_i.sample(n=10000, random_state=23)

# Define the directory path to save the DataFrame
directory = '../data/raw/'

# Save the sampled DataFrame as a CSV file in the specified directory
df_i.to_csv(directory + 'df_i.csv', index=False)

# Display the first few rows of the sampled DataFrame
print(df_i.head(10))

# Get info about DF
print(df_i.info())
# Out:
#          IncidentNumber DateOfCall  CalYear TimeOfCall  HourOfCall  \
# 571992  043453-28032023  28-Mar-23     2023   23:08:30          23
# 632053  144295-18092023  18-Sep-23     2023   08:19:06           8
# 665546  197526-16122023  16-Dec-23     2023   12:37:18          12
# 628180  137787-08092023  08-Sep-23     2023   08:33:16           8
# 631582  143525-16092023  16-Sep-23     2023   23:20:57          23
# 657043  184192-24112023  24-Nov-23     2023   03:36:47           3
# 593470  079155-03062023  03-Jun-23     2023   22:43:46          22
# 579969  056510-24042023  24-Apr-23     2023   06:12:08           6
# 622135  127526-22082023  22-Aug-23     2023   15:07:37          15
# 618769  122000-12082023  12-Aug-23     2023   21:35:23          21
#
#           IncidentGroup      StopCodeDescription     SpecialServiceType  \
# 571992  Special Service          Special Service   Effecting entry/exit
# 632053      False Alarm                      AFA                    NaN
# 665546      False Alarm                      AFA                    NaN
# 628180      False Alarm  False alarm - Malicious                    NaN
# 631582      False Alarm                      AFA                    NaN
# 657043             Fire           Secondary Fire                    NaN
# 593470  Special Service          Special Service  Making Safe (not RTC)
# 579969      False Alarm                      AFA                    NaN
# 622135  Special Service          Special Service   Effecting entry/exit
# 618769  Special Service          Special Service            Advice Only
#
#          PropertyCategory                                       PropertyType  \
# 571992           Dwelling  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 632053           Dwelling  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 665546    Non Residential                                       Single shop
# 628180  Other Residential    Boarding House/B&B for homeless/asylum seekers
# 631582           Dwelling  Purpose Built Flats/Maisonettes - Up to 3 stor...
# 657043            Outdoor                             Road surface/pavement
# 593470           Dwelling  Purpose Built Flats/Maisonettes - 4 to 9 storeys
# 579969           Dwelling                          House - single occupancy
# 622135           Dwelling     Converted Flat/Maisonettes - 3 or more storeys
# 618769           Dwelling       Converted Flat/Maisonette - Up to 2 storeys
#
#         ... FirstPumpArriving_AttendanceTime  \
# 571992  ...                            140.0
# 632053  ...                            283.0
# 665546  ...                            521.0
# 628180  ...                            273.0
# 631582  ...                            254.0
# 657043  ...                            217.0
# 593470  ...                            420.0
# 579969  ...                            353.0
# 622135  ...                            315.0
# 618769  ...                            223.0
#
#        FirstPumpArriving_DeployedFromStation  \
# 571992                       Stoke Newington
# 632053                               Chelsea
# 665546                              Chiswick
# 628180                                Euston
# 631582                             Wimbledon
# 657043                               Peckham
# 593470                             Tottenham
# 579969                               Ruislip
# 622135                                Ealing
# 618769                               Clapham
#
#        SecondPumpArriving_AttendanceTime  \
# 571992                               NaN
# 632053                             358.0
# 665546                             572.0
# 628180                             356.0
# 631582                             441.0
# 657043                               NaN
# 593470                               NaN
# 579969                               NaN
# 622135                               NaN
# 618769                               NaN
#
#         SecondPumpArriving_DeployedFromStation  NumStationsWithPumpsAttending  \
# 571992                                     NaN                            1.0
# 632053                              Kensington                            2.0
# 665546                                  Heston                            2.0
# 628180                               Islington                            2.0
# 631582                                 Tooting                            2.0
# 657043                                     NaN                            1.0
# 593470                                     NaN                            1.0
# 579969                                     NaN                            1.0
# 622135                                     NaN                            1.0
# 618769                                     NaN                            1.0
#
#        NumPumpsAttending PumpCount PumpMinutesRounded Notional Cost (£)  \
# 571992               1.0         1                 60               364
# 632053               2.0         2                 60               388
# 665546               2.0         2                 60               388
# 628180               2.0         2                 60               388
# 631582               2.0         2                 60               388
# 657043               1.0         1                 60               388
# 593470               1.0         1                 60               388
# 579969               1.0         1                 60               388
# 622135               1.0         1                 60               388
# 618769               1.0         1                 60               388
#
#        NumCalls
# 571992      1.0
# 632053      1.0
# 665546      1.0
# 628180      1.0
# 631582      1.0
# 657043      2.0
# 593470      1.0
# 579969      1.0
# 622135      1.0
# 618769      1.0
#
# [10 rows x 39 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 571992 to 655798
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   IncidentNumber                          10000 non-null  object
#  1   DateOfCall                              10000 non-null  object
#  2   CalYear                                 10000 non-null  int64
#  3   TimeOfCall                              10000 non-null  object
#  4   HourOfCall                              10000 non-null  int64
#  5   IncidentGroup                           10000 non-null  object
#  6   StopCodeDescription                     10000 non-null  object
#  7   SpecialServiceType                      3737 non-null   object
#  8   PropertyCategory                        10000 non-null  object
#  9   PropertyType                            10000 non-null  object
#  10  AddressQualifier                        10000 non-null  object
#  11  Postcode_full                           4120 non-null   object
#  12  Postcode_district                       10000 non-null  object
#  13  UPRN                                    10000 non-null  float64
#  14  USRN                                    10000 non-null  int64
#  15  IncGeo_BoroughCode                      10000 non-null  object
#  16  IncGeo_BoroughName                      10000 non-null  object
#  17  ProperCase                              10000 non-null  object
#  18  IncGeo_WardCode                         9981 non-null   object
#  19  IncGeo_WardName                         9981 non-null   object
#  20  IncGeo_WardNameNew                      9981 non-null   object
#  21  Easting_m                               4120 non-null   float64
#  22  Northing_m                              4120 non-null   float64
#  23  Easting_rounded                         10000 non-null  int64
#  24  Northing_rounded                        10000 non-null  int64
#  25  Latitude                                4120 non-null   float64
#  26  Longitude                               4120 non-null   float64
#  27  FRS                                     10000 non-null  object
#  28  IncidentStationGround                   10000 non-null  object
#  29  FirstPumpArriving_AttendanceTime        9476 non-null   float64
#  30  FirstPumpArriving_DeployedFromStation   9476 non-null   object
#  31  SecondPumpArriving_AttendanceTime       3640 non-null   float64
#  32  SecondPumpArriving_DeployedFromStation  3640 non-null   object
#  33  NumStationsWithPumpsAttending           9908 non-null   float64
#  34  NumPumpsAttending                       9908 non-null   float64
#  35  PumpCount                               10000 non-null  int64
#  36  PumpMinutesRounded                      10000 non-null  int64
#  37  Notional Cost (£)                       10000 non-null  int64
#  38  NumCalls                                10000 non-null  float64
# dtypes: float64(10), int64(8), object(21)
# memory usage: 3.1+ MB
# None
